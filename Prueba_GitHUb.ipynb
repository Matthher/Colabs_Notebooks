# %% [markdown]
# <a href="https://colab.research.google.com/github/Matthher/Colabs_Notebooks/blob/main/Prueba_GitHUb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
columna1 = [23,19,20,19,22,21,23]
columna2 = [152,170,160,178,186,163,165]
columna3 = ['FIS','LAEC','BIO','BIOM','BIO','LAEC','MATE']
columna4 = ['rojo','rojo','azul','naranja','celeste','rosa','verde']
columna5 = ['WAPP','INSTA','TIKTOK','INSTA','FACE','INSTA','TIKTOK']

# %%
datos = pd.DataFrame( { 'Edad':columna1, 'Estatura':columna2, 'Carrera':columna3, 'Color':columna4, 'Red':columna5 } )

# %%
datos
# Out:
#    Edad  Estatura Carrera    Color     Red
# 0    23       152     FIS     rojo    WAPP
# 1    19       170    LAEC     rojo   INSTA
# 2    20       160     BIO     azul  TIKTOK
# 3    19       178    BIOM  naranja   INSTA
# 4    22       186     BIO  celeste    FACE
# 5    21       163    LAEC     rosa   INSTA
# 6    23       165    MATE    verde  TIKTOK
